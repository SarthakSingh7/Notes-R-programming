# %% [markdown]
# # Assignment 3 Question 4
#
# Data Science for Engineers NPTEL

# %% [markdown]
# Find the t-statistic for the sample data given that the population mean of the distribution is 8.
#
# Sample Data:
#
# ![image.png](attachment:image.png)

# %%
samples = c(5,5,7,5,4,5,4,7,5,4)
# given mean 8

t.test(samples, mu= 8)
# Out:
# 	One Sample t-test
#
# data:  samples
# t = -8.3331, df = 9, p-value = 1.596e-05
# alternative hypothesis: true mean is not equal to 8
# 95 percent confidence interval:
#  4.312746 5.887254
# sample estimates:
# mean of x
#       5.1

# %% [markdown]
# ## t-statistic
#
# t = -8.3331

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment 3 Question 5
#
# Data Science for Engineers NPTEL

# %% [markdown]
# ***
# Find F-statistic for the following sample sets generated from the same distribution
#
# Sample Data 1:
#
# ![image.png](attachment:image.png)
#
# Sample Data 2:
#
# ![image-2.png](attachment:image-2.png)

# %%
sample1 = c(8,6,5,6,7,7,4)
sample2 = c(15,15,11,9,13,5,12)

var.test(sample1, sample2)
# Out:
# 	F test to compare two variances
#
# data:  sample1 and sample2
# F = 0.1434, num df = 6, denom df = 6, p-value = 0.0324
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  0.02463956 0.83453113
# sample estimates:
# ratio of variances
#          0.1433962

# %% [markdown]
# ## F-statistic
#
# F = 0.1434

# %% [markdown]
# ***
#
# # Assignment 3 Question 6
#
# Data Science for Engineers NPTEL

# %% [markdown]
# ***
# Find the F-statistic for the following sample sets generated from the distributions with population variances 3 and 7 respectively
#
# Sample Data 1:
#
# ![image.png](attachment:image.png)
#
# Sample Data 2:
#
# ![image-2.png](attachment:image-2.png)

# %%
sampleA = c(16,12,34,27,32,27,31)
sampleB = c(25,23,14,25,32,27,32)

var_sampleA = var(sampleA)/3

var_sampleB = var(sampleB)/7

f_test_formula = var_sampleA / var_sampleB   # formula used in F-test 

round(f_test_formula, 2)  # rounding the answer till 2 decimal places
# Out:
# [1] 4.36

# %%
#Note: the above method was used because the sample size is small so tis method willl not work

var.test(var_sampleA, var_sampleB)
# Out:
# Error in var.test.default(var_sampleA, var_sampleB): not enough 'x' observations
# Traceback:
#
# 1. var.test(var_sampleA, var_sampleB)
# 2. var.test.default(var_sampleA, var_sampleB)
# 3. stop("not enough 'x' observations")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
#
# # Assignment 3 Question 7
#
# Data Science for Engineers NPTEL

# %% [markdown]
# ***
# When will you reject the Null hypothesis?
# 1. p value greater than α
# 2. p value less than α
# 3. p value equal to α
# 4. None of the above

# %% [markdown]
# Answer: 2. p value less than α

# %% [markdown]
# ***
#
# # Assignment 3 Question 8
#
# Data Science for Engineers NPTEL

# %% [markdown]
# ***
# A standard normal density function is shown below. The area of the shaded region is
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The required probability is
# ## P(−2 < Z < 2)
#
# ### P(−2 < Z < 2) = P(Z < 2) - P(Z < -2)

# %%
pnorm(2,0,1) - pnorm(-2,0,1)
# Out:
# [1] 0.9544997

# %% [markdown]
# ## The area of the shaded region is
#
# 0.9544

# %% [markdown]
# read : https://www.geeksforgeeks.org/normal-distribution-in-r/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
#
# # Assignment 3 Question 9
#
# Data Science for Engineers NPTEL

# %% [markdown]
# ***
# A talent exam is conducted annually which has a mean score of 200 and a standard deviation of 30. If a student's Z-score is 1.50, what was his score in the exam?

# %%
mean = 200 
std = 30
z = 1.5

x = mean + (z * std) # see formula below

print(x)
# Out:
# [1] 245

# %% [markdown]
#  his score in the exam = 245

# %% [markdown]
# ![IMG_20220924_205945524_2.jpg](attachment:IMG_20220924_205945524_2.jpg)

# %% [markdown]
# ***
#
# # Assignment 3 Question 10
#
# Data Science for Engineers NPTEL

# %% [markdown]
# ***
# A car company purchases engine blocks from suppliers A, B, and C. Out of the 100 units supplied by A, two units were found to be defective. Similarly, out of 200 and 300 units supplied by B and C, the number units found to be defective were 10 and 15 respectively. If a quality control person of the car company picks up a block and if the selected block is from A, what is the probability that the block is defective?

# %%
A = 100
defective_A = 2
prob_A_def = defective_A / A

print(prob_A_def)
# Out:
# [1] 0.02

# %% [markdown]
# Probability A is defective = 0.02
